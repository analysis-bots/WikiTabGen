# %%
import pandas as pd

# %%
def fetch_results(path, model, method):
    table = pd.read_csv(path).iloc[100]
    table['Model'] = model
    table['Method'] = method
    return table

# %%
gpt4_ft_exact = fetch_results("DATA/gpt_4_turbo_w_break_full_table_20240928-102819/scores_100.csv", "GPT4-Turbo", "Full Table")
gpt4_rbr_exact = fetch_results("DATA/gpt_4_turbo_w_break_generic_keys_rows_20240928-130728/scores_100.csv", "GPT4-Turbo", "Row-by-Row")
gpt4_cbc_exact = fetch_results("DATA/gpt_4_turbo_w_break_generic_keys_cells_20240928-205138/scores_100.csv", "GPT4-Turbo", "Cell-by-Cell")
gpt4o_ft_exact = fetch_results("DATA/gpt_4o_full_table_20240727-211636/scores_100.csv", "GPT-4o", "Full Table")
gpt4o_rbr_exact = fetch_results("DATA/gpt_4o_generic_keys_rows_20240728-073304/scores_100.csv", "GPT-4o", "Row-by-Row")
gpt4o_cbc_exact = fetch_results("DATA/gpt_4o_generic_keys_cells_20240926-090024/scores_100.csv", "GPT-4o", "Cell-by-Cell")
llama70b_ft_exact = fetch_results("DATA/Meta_Llama_3.1_70B_Instruct_full_table_20240726-231535/scores_100.csv", "LLaMa3.1_70b", "Full Table")
llama70b_rbr_exact = fetch_results("DATA/Meta_Llama_3.1_70B_Instruct_generic_keys_rows_20240728-073256/scores_100.csv", "LLaMa3.1_70b", "Row-by-Row")
llama70_cbc_exact = fetch_results("DATA/Meta_Llama_3.1_70B_Instruct_generic_keys_cells_20240921-103732/scores_100.csv", "LLaMa3.1_70b", "Cell-by-Cell")
llama405b_ft_exact = fetch_results("DATA/Meta_Llama_3.1_405B_Instruct_full_table_20240908-111922/scores_100.csv", "LLaMa3.1_405b", "Full Table")
llama405b_rbr_exact = fetch_results("DATA/Meta_Llama_3.1_405B_Instruct_generic_keys_rows_20240913-213247/scores_100.csv", "LLaMa3.1_405b", "Row-by-Row")
llama405b_cbc_exact = fetch_results("DATA/Meta_Llama_3.1_405B_Instruct_generic_keys_cells_20240921-104204/scores_100.csv", "LLaMa3.1_405b", "Cell-by-Cell")

# %%
res_df = pd.concat([
    gpt4_ft_exact,
    gpt4_rbr_exact,
    gpt4_cbc_exact,
    gpt4o_ft_exact,
    gpt4o_rbr_exact,
    gpt4o_cbc_exact,
    llama70b_ft_exact,
    llama70b_rbr_exact,
    llama70_cbc_exact,
    llama405b_ft_exact,
    llama405b_rbr_exact,
    llama405b_cbc_exact
], axis=1).drop('Table').T.set_index(['Model', 'Method'])

res_df
# Out:
#                            Keys_Recall Keys_Precision Keys_F1_Score  \
# Model         Method
# GPT4-Turbo    Full Table      0.434336       0.660574      0.468198
#               Row-by-Row      0.539057       0.576041      0.532342
#               Cell-by-Cell    0.539057       0.576105      0.532345
# GPT-4o        Full Table      0.358026       0.660119      0.402515
#               Row-by-Row      0.539146       0.608148      0.535435
#               Cell-by-Cell    0.538868       0.606666      0.534965
# LLaMa3.1_70b  Full Table       0.46135       0.637689      0.499035
#               Row-by-Row      0.501704       0.555347      0.500174
#               Cell-by-Cell    0.501534       0.553406      0.499654
# LLaMa3.1_405b Full Table      0.441404       0.685967      0.487824
#               Row-by-Row      0.505423       0.615376      0.516812
#               Cell-by-Cell    0.504392       0.614215      0.515721
#
# ...

# %%
res_df.to_csv("RESULTS/t1_main_results_exact_match.csv")
