# %%
import pandas as pd

res = [
    ["LLaMa3.1-405b", "Full Table", "23.4", "25.4"],    
    ["GPT-4o", "Row by Row", "20.8", "23.1"],
    ["LLaMa3.1-70b", "Full Table", "20.0", "22.1"],
    ["GPT4-Turbo", "Row by Row", "18.9", "21.6"],
    ["GPT3.5-Turbo", "Full Table", "16.1", "18.0"],
    ["LLaMa2-70b", "Row by Row", "9.4", "10.5"],
    ["LLaMa2-13b", "Full Table", "7.5", "8.4"],    
    ["Gemma2", "Row by Row", "7.6", "8.4"]
]

df = pd.DataFrame(res)
df.columns = ["Model", "Method", "Exact Match", "Semantic Match"]
df
# Out:
#            Model      Method Exact Match Semantic Match
# 0  LLaMa3.1-405b  Full Table        23.4           25.4
# 1         GPT-4o  Row by Row        20.8           23.1
# 2   LLaMa3.1-70b  Full Table        20.0           22.1
# 3     GPT4-Turbo  Row by Row        18.9           21.6
# 4   GPT3.5-Turbo  Full Table        16.1           18.0
# 5     LLaMa2-70b  Row by Row         9.4           10.5
# 6     LLaMa2-13b  Full Table         7.5            8.4
# 7         Gemma2  Row by Row         7.6            8.4

# %%
df.to_csv("RESULTS/all_models.csv", index=False)
